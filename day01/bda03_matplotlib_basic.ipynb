kB 6.2 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Seaborn 설치
# ```shell
# !pip install seaborn
# ```

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\dev\langs\python311\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: pandas>=1.2 in c:\dev\langs\python311\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\dev\langs\python311\lib\site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\langs\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ckddn\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\dev\langs\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\dev\langs\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ckddn\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---------------- ----------------------- 122.9/294.9 kB 1.8 MB/s eta 0:00:01
#    -------------------- ------------------- 153.6/294.9 kB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 266.2/294.9 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ###### 맷플롭립은 한글깨짐
# - 나눔폰트 옵션 사용
# - 폰트관리자 설정

# %%
# Matplotlib 사용 / 필수 차트 사용 시 항상 사용
import matplotlib.pyplot as plt # plt로 줄여씀
from matplotlib import rcParams, font_manager, rc
import warnings

# 나눔폰트 경로
font_path = 'C:/Windows/Fonts/Arial.ttf'
font = font_manager.FontProperties(fname=font_path, size=10).get_name()

# warning 표시 끄기
warnings.simplefilter('ignore') # 경고메시지 무시

# 기본폰트 설정
plt.rcParams['font.family'] = font

# 기본폰트 사이즈 설정
plt.rcParams['font.size'] = 14

# 기본차트 사이즈 변경
plt.rcParams['figure.figsize'] = (8, 6)

# 기본그리드 표시
plt.rcParams['axes.grid'] = True

# 한글화 후 마이너스 표시 네모를 정상출력
plt.rcParams['axes.unicode_minus'] = False

# %%
import numpy as np
import seaborn as sns #seaborn 추가로 로딩

# style => dark, darkgrid, white, whitegrid, ticks
# Seaboarn 사용시는 나눔고딕이 안됨. 맑음 고딕
sns.set(font=font, rc={'axes.unicode_minus':False}, style='darkgrid')

# %%
# 넘파이로 더미데이터 생성
## random == rand 양의 실수, randn
data = np.random.rand(50) # 정수로 랜덤 표준정규분포값 50개를 만듦
data
# Out:
# array([0.62099332, 0.46350411, 0.51744368, 0.94673375, 0.26184008,
#        0.81793356, 0.31395656, 0.40449061, 0.82967427, 0.76748932,
#        0.84416947, 0.34021206, 0.9388658 , 0.9963477 , 0.88323901,
#        0.21381642, 0.27379943, 0.64787808, 0.23513562, 0.97865539,
#        0.93624141, 0.24350081, 0.8466371 , 0.14937729, 0.20440545,
#        0.06040575, 0.69977288, 0.18192669, 0.37704928, 0.41761966,
#        0.22125306, 0.64462363, 0.29149579, 0.65323094, 0.24337027,
#        0.18833858, 0.3633679 , 0.1597067 , 0.04113854, 0.32586722,
#        0.85744328, 0.81621669, 0.85638086, 0.14034856, 0.77997671,
#        0.67212799, 0.93988563, 0.61727105, 0.5942892 , 0.73547984])

# %%
# 정수로 만들기
np.random.randint(1, 20, size=50)
# Out:
# array([17, 16, 15, 11,  6,  8,  3, 17,  1, 14, 14, 15,  8,  8,  6, 19,  7,
#        11,  5,  1,  3, 18, 12,  2, 12,  5, 11, 13,  5,  7, 18, 13, 10, 14,
#         6,  4,  7, 15, 12, 18,  4, 14,  5,  1, 15, 18,  3,  2, 17, 12],
#       dtype=int32)

# %%
## 차트 생성
plt.plot(np.random.randn(50), label='겨울기온')
plt.title('변화값')
plt.legend(loc='upper right')
plt.show()

# %%
## 시본 차트 생성
sns.set_style("darkgrid")
plt.plot(np.random.randn(50), label='겨울기온')
plt.title('변화값')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## 판다스로 읽은 데이터 차트화

# %%
# 판다스로 데이터
import pandas as pd

# %%
df = pd.read_csv('./data/sample_2.csv')
df
# Out:
#    Unnamed: 0 국적코드  성별    입국객수    전년동기
# 0           0  A01  남성  106320   85815
# 1           1  A01  여성  191436  125241
# 2           2  A31  남성     319     299
# 3           3  A31  여성      42      54
# 4           4  A18  남성  158912  124486
# 5           5  A18  여성  232943  163466

# %%
# 데이터프레임으로 맷플롭립 차트화
df[['성별', '입국객수']].plot()
plt.show()

# %%
# 히스토그램
df['입국객수'].hist(bins=5)
plt.title('2019년 10월 입국객수')
plt.show()

# %%
## 스캐터차트()
x = np.random.randint(-100, 100, 50) # -100~100사이에 50개만 랜덤
y = np.random.randint(-200, 200, 50)
size = np.random.randint(-200, 200, 50)
color = np.random.randint(0, 100, 50)

plt.scatter(x, y, s=size, c=color, alpha=0.5)
plt.colorbar()
plt.show()

# %%
## 파이차트
size = [2441, 2312, 1031, 1233]
label = ['A', 'B', 'AB', 'O']
color = ['darkmegenta', 'deeppink', 'hotpink', 'pink']

plt.axis('equal') # 가로축, 세로축 스케일 동일
plt.pie(size, labels=label, autopct='%.1f%%', explode=(0,0,0.1,0), colors=color)
plt.legent(loc='lower left')
plt.title("혈액형별 인구율")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 7
#       4 color = ['darkmegenta', 'deeppink', 'hotpink', 'pink']
#       6 plt.axis('equal') # 가로축, 세로축 스케일 동일
# ----> 7 plt.pie(size, labels=label, autopct='%.1f%%', explode=(0,0,0.1,0), colors=color)
#       8 plt.legent(loc='lower left')
#       9 plt.title("혈액형별 인구율")
#
# File c:\DEV\Langs\Python311\Lib\site-packages\matplotlib\pyplot.py:3762, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3739 @_copy_docstring_and_deprecators(Axes.pie)
#    3740 def pie(
#    3741     x: ArrayLike,
#    (...)
#    3760     data=None,
#    3761 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3762     return gca().pie(
#    3763         x,
#    3764         explode=explode,
#    3765         labels=labels,
#    3766         colors=colors,
#    3767         autopct=autopct,
#    3768         pctdistance=pctdistance,
#    3769         shadow=shadow,
#    3770         labeldistance=labeldistance,
#    3771         startangle=startangle,
#    3772         radius=radius,
#    3773         counterclock=counterclock,
#    3774         wedgeprops=wedgeprops,
#    3775         textprops=textprops,
#    3776         center=center,
#    3777         frame=frame,
#    3778         rotatelabels=rotatelabels,
#    3779         normalize=normalize,
#    3780         hatch=hatch,
#    3781         **({"data": data} if data is not None else {}),
#    3782     )
#
# File c:\DEV\Langs\Python311\Lib\site-packages\matplotlib\__init__.py:1486, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1483 @functools.wraps(func)
#    1484 def inner(ax, *args, data=None, **kwargs):
#    1485     if data is None:
# -> 1486         return func(
#    1487             ax,
#    1488             *map(sanitize_sequence, args),
#    1489             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1491     bound = new_sig.bind(ax, *args, **kwargs)
#    1492     auto_label = (bound.arguments.get(label_namer)
#    1493                   or bound.kwargs.get(label_namer))
#
# File c:\DEV\Langs\Python311\Lib\site-packages\matplotlib\axes\_axes.py:3334, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3331 x += expl * math.cos(thetam)
#    3332 y += expl * math.sin(thetam)
# -> 3334 w = mpatches.Wedge((x, y), radius, 360. * min(theta1, theta2),
#    3335                    360. * max(theta1, theta2),
#    3336                    facecolor=get_next_color(),
#    3337                    hatch=next(hatch_cycle),
#    3338                    clip_on=False,
#    3339                    label=label)
#    3340 w.set(**wedgeprops)
#    3341 slices.append(w)
#
# File c:\DEV\Langs\Python311\Lib\site-packages\matplotlib\patches.py:1237, in Wedge.__init__(self, center, r, theta1, theta2, width, **kwargs)
#    1225 @_docstring.dedent_interpd
#    1226 def __init__(self, center, r, theta1, theta2, *, width=None, **kwargs):
#    1227     """
#    1228     A wedge centered at *x*, *y* center with radius *r* that
#    1229     sweeps *theta1* to *theta2* (in degrees).  If *width* is given,
#    (...)
#    1235     %(Patch:kwdoc)s
#    1236     """
# -> 1237     super().__init__(**kwargs)
#    1238     self.center = center
#    1239     self.r, self.width = r, width
#
# File c:\DEV\Langs\Python311\Lib\site-packages\matplotlib\patches.py:84, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      82 else:
#      83     self.set_edgecolor(edgecolor)
# ---> 84     self.set_facecolor(facecolor)
#      86 self._linewidth = 0
#      87 self._unscaled_dash_pattern = (0, None)  # offset, dash
#
# File c:\DEV\Langs\Python311\Lib\site-packages\matplotlib\patches.py:403, in Patch.set_facecolor(self, color)
#     395 """
#     396 Set the patch face color.
#     397
#    (...)
#     400 color : :mpltype:`color` or None
#     401 """
#     402 self._original_facecolor = color
# --> 403 self._set_facecolor(color)
#
# File c:\DEV\Langs\Python311\Lib\site-packages\matplotlib\patches.py:391, in Patch._set_facecolor(self, color)
#     389     color = mpl.rcParams['patch.facecolor']
#     390 alpha = self._alpha if self._fill else 0
# --> 391 self._facecolor = colors.to_rgba(color, alpha)
#     392 self.stale = True
#
# File c:\DEV\Langs\Python311\Lib\site-packages\matplotlib\colors.py:314, in to_rgba(c, alpha)
#     312     rgba = None
#     313 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 314     rgba = _to_rgba_no_colorcycle(c, alpha)
#     315     try:
#     316         _colors_full_map.cache[c, alpha] = rgba
#
# File c:\DEV\Langs\Python311\Lib\site-packages\matplotlib\colors.py:391, in _to_rgba_no_colorcycle(c, alpha)
#     387             raise ValueError(
#     388                 f"Invalid string grayscale value {orig_c!r}. "
#     389                 f"Value must be within 0-1 range")
#     390         return c, c, c, alpha if alpha is not None else 1.
# --> 391     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     392 # turn 2-D array into 1-D array
#     393 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'darkmegenta'
