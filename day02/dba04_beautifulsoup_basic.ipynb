# %% [markdown]
# ### BeautifulSoup 기초
#
# - 웹 페이지 정제 라이브러리 - 웹페이지 내용을 읽어오고 필요한 내용을 발췌, 데이터로 받아오는 작업
# - OpenAPI나 데이터를 제공해주지 않는 서비스에서 데이터를 긁어오기 위한 기본 작업
#
# #### BeatifulSoup 설치
# ```shell
# !pip install beautifulsoup4
# ```

# %%
# !pip install beautifulsoup4

# %%
# !python -m pip install --upgrade pip

# %% [markdown]
# - 웹크롤링 가능여부 판단
#     - 웹사이트 열고, 페이지 소스 보기를 했을 때 HTML 소스가 일반적으로 표시되어야 함
#     - 네이버 등 대형포털은 크롤링 방지가 되어 있음

# %% [markdown]
# - 뷰티플수프 사용
# - requests 인터넷 모듈도 같이 사용

# %%
from bs4 import BeautifulSoup # bs4 = BeautifulSoup4 # 줄임말 보통 안씀
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 from bs4 import BeautifulSoup # bs4 = BeautifulSoup4 # 줄임말 보통 안씀
# ----> 2 import requests
#
# ModuleNotFoundError: No module named 'requests'

# %%
## 크롤링 사이트 멜론 : https://www.melon.com/chart/index.htm
## 406 에러 : 클라이언트 오류 응답 코드
## 크롤링 방지 사이트 : 다나와, 구글, 네이버 등
## https://www.bluer.co.kr/search?query=%EC%86%8C%EB%A3%A1%ED%8F%AC&isSearchName=false&location=
url = 'https://www.bluer.co.kr/search?query=%EC%86%8C%EB%A3%A1%ED%8F%AC&isSearchName=false&location=' # 여기를 크롤링 할 거다

response = requests.get(url)  # 프로세스 = 요청에 대한 응답

if response.status_code == 200: # 200 OK, 404 Not Found,500 Internal Error
    print(response.text)
    soup = BeautifulSoup(html, 'html.parser')
    print(soup)
    # soup.select()
else:
    print(response.status_code)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no"/>
#
# <title>블루리본 서베이</title>
#
# <meta name="_csrf" content="3aee36e9-27d1-4062-b95e-e6146271da82"/>
# <meta name="_csrf_header" content="X-CSRF-TOKEN"/>
# <meta name="_csrf_param" content="_csrf"/>
#
#
#
# <meta name="robots" content="index,follow">
# <meta name="googlebot" content="index,follow">
# <link href="http://www.bluer.co.kr" rel="canonical">
# <meta name="subject" content="한국대표 미식평가사이트, 블루리본"/>
# <meta name="description" content="추천맛집 소개, 레스토랑 평가 및 검색, 와인정보, 개업 음식점 등 식당 정보 제공."/>
# <meta name="keywords" content="맛집,추천,레스토랑,평가,와인,음식점,식당"/>
# <meta name="copyright" content="©Copyright 2021 BlueRibbon | All Rights Reserved"/>
#
# <meta property="og:type" content="website"/>
# <meta property="og:url" content="http://www.bluer.co.kr"/>
# ...

# %% [markdown]
# #### 단순 웹크롤링은 현재 대부분 사이트가 막고 있음
